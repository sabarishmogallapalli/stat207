# %% [markdown]
# # STAT 207 Lab Assignment 12 - Individual Part - [21 Points]
#
#
#
# ## <u>Case Study</u>: Classifying Airbnb Superhost Status
#
# Suppose that you have a spare room in your house (in Seattle) and you are considering advertising this room to guests on Airbnb. Airbnb superhosts are considered to be experienced hosts who provide a shining example for other hosts, and extraordinary experiences for their guests. Once a host reaches Superhost status, a superhost badge will automatically appear on their listing and profile to help guests identify them. You would like to assess your chances of being named a superhost with your property.
#
# The following dataset is a sample (assume random) of available Airbnb listings in Seattle, WA. These listings were collected in January 2016, and filtered to just contain listings from the five most popular Seattlbe neighborhoods (for Airbnb listings) and just contain listings that are either in a house or apartment property.
#
# This dataset contains the following variables.
#
# **Listing Information**
# The dataset contains the following information about the Airbnb *listing*:
# * <u>price</u>: price of the listing (per night)(in US dollars)
# * <u>review_scores_rating</u>: the average rating of the listing [0,100] (100 is the best)
# * <u>number_of_reviews</u>: the number of reviews for the listing
# * <u>security_deposit</u>: the security deposit required for the listing (in US dollars)
# * <u>cleaning_fee</u>: the cleaning fee required for the listing (in US dollars)
# * <u>neighborhood</u>: the neighborhood of Seattle the listing is located in
# * <u>property_type</u>: is the listing in a 'House' or 'Apartment'
# * <u>room_type</u>: is the listing a 'Entire home/apt', 'Private room', or 'Shared room'
# * <u>accommodates</u>: how many guests will the listing accommodate
# * <u>bathrooms</u>:how many bathrooms does the listing have
# * <u>beds</u>: how many beds does the listing have
#
# **Host Information**
# The dataset also contains the following information about the *host* of the given Airbnb listing:
# * <u>host_is_superhost</u>: is the host a "superhost": t=True, f=False
# * <u>host_has_profile_pic</u>: does the host have a profile pic in their bio: t=True, f=False
# * <u>host_response_time</u>: how fast will the host respond to requests (on average)
#
# ## Research Goals
#
# ### Primary Research Goal
# The primary research goal that we will pursue in this lab will be to build a predictive model that effectively predicts the `probability a Seattle Airbnb host is a **superhost**` for *new Seattle Airbnb listings/hosts* given some combination of the `remaining explanatory variables`.
#
# ### Secondary Research Goal
#
# Ideally, we would also like to interpret our final model.
#
#
#
# ## Points
#
# <p>&nbsp;</p>
# <table style="border: none;border-collapse: collapse;width:102pt;">
#     <tbody>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:700;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;width:51pt;">Problem</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:700;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:general;vertical-align:bottom;border:.5pt solid windowtext;border-left:none;width:51pt;">Points</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.1</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.25</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.2</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.25</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.3</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.4.1</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.4.2</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.4.3</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.1</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.2</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">2</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.3</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.4</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">3.5</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.1</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">2</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.2</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">2</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.3</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">5.1</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">5.2</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">5.3</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">5.4</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#     </tbody>
# </table>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
import statsmodels.formula.api as smf
from sklearn.preprocessing import StandardScaler

import warnings
from sklearn.exceptions import ConvergenceWarning
# Ignore scikit-learn ConvergenceWarnings
warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=UserWarning)
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## 1. Basic Data Examination and Cleaning
#
# ### 1.1. Reading the Dataset
#
# 1. Read this csv file into a dataframe.
#
# 2. Display your dataframe.
#
# 3. Show how many rows your dataframe has.

# %%
df=pd.read_csv('seattle_airbnb_listings_cleaned.csv')
df.head()
# Out:
#    price  review_scores_rating  number_of_reviews  security_deposit  \
# 0    300                   100                 24               500
# 1    149                    96                 11               300
# 2     95                    95                 79               150
# 3    105                   100                 13               500
# 4    140                    99                 30               250
#
#    cleaning_fee neighborhood property_type        room_type  accommodates  \
# 0            95  Wallingford         House  Entire home/apt             5
# 1           105  Wallingford     Apartment  Entire home/apt             6
# 2            40  Wallingford     Apartment  Entire home/apt             3
# 3            50  Wallingford         House     Private room             2
# 4            65  Wallingford         House  Entire home/apt             2
#
#    bathrooms  beds  host_response_time  host_response_rate host_is_superhost  \
# 0        1.5     3  within a few hours                 1.0                 t
# 1        1.0     3      within an hour                 1.0                 f
# 2        1.0     2      within an hour                 1.0                 f
# 3        2.0     1  within a few hours                 1.0                 t
# 4        1.0     1      within an hour                 1.0                 t
#
#   host_has_profile_pic host_identity_verified
# 0                    t                      t
# 1                    t                      t
# 2                    t                      t
# 3                    t                      t
# 4                    t                      t

# %%
rows = df.shape[0]
print(f"Rows: {rows}")
# Out:
# Rows: 339

# %% [markdown]
# ### 1.2. 0/1 Response Variable
#
# Create a new 0/1 variable in your dataset in which `superhosts=1` and `nonsuperhosts=0`.

# %%
df['y'] = df['host_is_superhost'].replace({'t':1, 'f':0})
df.head()
# Out:
#    price  review_scores_rating  number_of_reviews  security_deposit  \
# 0    300                   100                 24               500
# 1    149                    96                 11               300
# 2     95                    95                 79               150
# 3    105                   100                 13               500
# 4    140                    99                 30               250
#
#    cleaning_fee neighborhood property_type        room_type  accommodates  \
# 0            95  Wallingford         House  Entire home/apt             5
# 1           105  Wallingford     Apartment  Entire home/apt             6
# 2            40  Wallingford     Apartment  Entire home/apt             3
# 3            50  Wallingford         House     Private room             2
# 4            65  Wallingford         House  Entire home/apt             2
#
#    bathrooms  beds  host_response_time  host_response_rate host_is_superhost  \
# 0        1.5     3  within a few hours                 1.0                 t
# 1        1.0     3      within an hour                 1.0                 f
# 2        1.0     2      within an hour                 1.0                 f
# 3        2.0     1  within a few hours                 1.0                 t
# 4        1.0     1      within an hour                 1.0                 t
#
#   host_has_profile_pic host_identity_verified  y
# 0                    t                      t  1
# 1                    t                      t  0
# 2                    t                      t  0
# 3                    t                      t  1
# 4                    t                      t  1

# %% [markdown]
# ### 1.3. Train-Test-Split
#
# Create a training dataset and a test dataset from your dataframe using a random state of `101` and a test dataset size that is a random sample of about 20% of the observations from the original dataset.

# %%
df_test, df_train = train_test_split(df, test_size=0.2, random_state=101)

# %%
df_test.head()
# Out:
#      price  review_scores_rating  number_of_reviews  security_deposit  \
# 231     69                    85                255               100
# 259    125                    99                 21               200
# 165    165                    95                  4               150
# 89     114                   100                  4               500
# 295    275                    96                 67               200
#
#      cleaning_fee neighborhood property_type        room_type  accommodates  \
# 231            72     Broadway     Apartment  Entire home/apt             3
# 259            40     Broadway     Apartment  Entire home/apt             2
# 165            65     Belltown     Apartment  Entire home/apt             3
# 89             50        Minor         House  Entire home/apt             6
# 295           145      Fremont         House  Entire home/apt             8
#
#      bathrooms  beds  host_response_time  host_response_rate  \
# 231        1.0     1      within an hour                 1.0
# 259        1.0     1        within a day                 1.0
# 165        1.0     2      within an hour                 1.0
# 89         1.0     4  within a few hours                 1.0
# 295        2.5     3      within an hour                 1.0
#
#     host_is_superhost host_has_profile_pic host_identity_verified  y
# 231                 f                    t                      f  0
# 259                 f                    t                      t  0
# 165                 f                    t                      t  0
# 89                  f                    t                      t  0
# 295                 t                    t                      t  1

# %%
df_train.head()
# Out:
#      price  review_scores_rating  number_of_reviews  security_deposit  \
# 172     59                    95                  4               150
# 38     109                    99                 36               100
# 242     61                    95                 14               250
# 64      95                    97                 88               100
# 181    147                    98                 55               250
#
#      cleaning_fee neighborhood property_type        room_type  accommodates  \
# 172            50     Broadway     Apartment     Private room             1
# 38             60  Wallingford     Apartment  Entire home/apt             4
# 242            39     Broadway         House     Private room             2
# 64             30  Wallingford         House     Private room             2
# 181           125     Broadway         House  Entire home/apt             6
#
#      bathrooms  beds  host_response_time  host_response_rate  \
# 172        1.0     1  within a few hours                 1.0
# 38         1.0     3      within an hour                 1.0
# 242        2.0     1  within a few hours                 1.0
# 64         1.0     1      within an hour                 1.0
# 181        2.5     3  within a few hours                 1.0
#
#     host_is_superhost host_has_profile_pic host_identity_verified  y
# 172                 f                    t                      t  0
# 38                  t                    t                      t  1
# 242                 f                    t                      t  0
# 64                  t                    t                      t  1
# 181                 t                    t                      t  1

# %% [markdown]
# ### 1.4. Numerical Explanatory Variable Scaling
#
# #### 1.4.1. Numerical Explanatory Variable Standard Deviations
#
# First, calculate the standard deviation of each of your numerical explanatory variables in your training dataset.

# %%
num_df_train = df_train.drop(['neighborhood','property_type','room_type','host_response_time','host_is_superhost','host_has_profile_pic','host_identity_verified'],axis=1)
num_df_train
# Out:
#      price  review_scores_rating  number_of_reviews  security_deposit  \
# 172     59                    95                  4               150
# 38     109                    99                 36               100
# 242     61                    95                 14               250
# 64      95                    97                 88               100
# 181    147                    98                 55               250
# ..     ...                   ...                ...               ...
# 157    149                    93                 95               300
# 247    138                    94                 96               100
# 70      49                    88                 79               100
# 104    115                   100                  3               100
# 312    200                    90                 10               500
#
#      cleaning_fee  accommodates  bathrooms  beds  host_response_rate  y
# 172            50             1        1.0     1                1.00  0
# 38             60             4        1.0     3                1.00  1
# 242            39             2        2.0     1                1.00  0
# 64             30             2        1.0     1                1.00  1
# 181           125             6        2.5     3                1.00  1
# ..            ...           ...        ...   ...                 ... ..
# 157            60             3        1.0     1                1.00  1
# 247            50             2        1.0     1                0.53  0
# 70              5             2        1.0     1                1.00  0
# 104            10             3        1.0     1                1.00  0
# 312           100             6        2.5     4                0.75  0
#
# [68 rows x 10 columns]

# %%
std = num_df_train.std()
std
# Out:
# price                    71.534533
# review_scores_rating     10.950884
# number_of_reviews        39.025081
# security_deposit        249.000141
# cleaning_fee             27.668900
# accommodates              1.733064
# bathrooms                 0.419823
# beds                      0.921407
# host_response_rate        0.087232
# y                         0.481438
# dtype: float64

# %% [markdown]
# #### 1.4.2. Scaling the Numerical Explanatory Variables in the Training Dataset
#
# Just like we saw in a linear regression model, if the standard deviations of the numerical explanatory variables in a logistic regression model are not all roughly equal, then we cannot interpret the magnitude of the slopes as reflecting the predictive power that the corresponding variable brings to the model.
#
# Because we'd now like to (ideally) interpret the slope magnitudes of our model in this way, z-score scale the numerical explanatory variables in your training dataset (using the TRAINING dataset means and standard deviations.)

# %%
scaler = StandardScaler()
scaled_exp_vars = scaler.fit_transform(num_df_train)
num_df_train = pd.DataFrame(scaled_exp_vars,columns=num_df_train.columns)
num_df_train.head()
# Out:
#       price  review_scores_rating  number_of_reviews  security_deposit  \
# 0 -0.912301              0.143405          -0.756230         -0.415599
# 1 -0.208141              0.511388           0.069853         -0.617896
# 2 -0.884135              0.143405          -0.498079         -0.011007
# 3 -0.405306              0.327397           1.412236         -0.617896
# 4  0.327020              0.419392           0.560339         -0.011007
#
#    cleaning_fee  accommodates  bathrooms      beds  host_response_rate  \
# 0     -0.040694     -1.316480  -0.317603 -0.739630            0.416102
# 1      0.323410      0.427428  -0.317603  1.447102            0.416102
# 2     -0.441208     -0.735177   2.082065 -0.739630            0.416102
# 3     -0.768901     -0.735177  -0.317603 -0.739630            0.416102
# 4      2.690084      1.590034   3.281899  1.447102            0.416102
#
#           y
# 0 -0.738549
# 1  1.354006
# 2 -0.738549
# 3  1.354006
# 4  1.354006

# %% [markdown]
# #### 1.4.3. Scaling the Numerical Explanatory Variables in the Test Dataset
#
# Then, z-score scale the numerical explanatory variables in your TEST dataset (using the means and standard deviations from the TRAINING dataset).

# %%
num_df_test = df_test.drop(['neighborhood','property_type','room_type','host_response_time','host_is_superhost','host_has_profile_pic','host_identity_verified'],axis=1)
num_df_test
# Out:
#      price  review_scores_rating  number_of_reviews  security_deposit  \
# 231     69                    85                255               100
# 259    125                    99                 21               200
# 165    165                    95                  4               150
# 89     114                   100                  4               500
# 295    275                    96                 67               200
# ..     ...                   ...                ...               ...
# 87     108                   100                  8               120
# 63      40                   100                  1               350
# 326    150                   100                  1               300
# 337    175                    96                 29               500
# 11     135                    97                 71               200
#
#      cleaning_fee  accommodates  bathrooms  beds  host_response_rate  y
# 231            72             3        1.0     1                1.00  0
# 259            40             2        1.0     1                1.00  0
# 165            65             3        1.0     2                1.00  0
# 89             50             6        1.0     4                1.00  0
# 295           145             8        2.5     3                1.00  1
# ..            ...           ...        ...   ...                 ... ..
# 87             25             2        1.0     2                0.83  1
# 63             35             1        1.0     1                0.90  0
# 326            85             6        1.0     3                0.92  0
# 337            95             6        2.0     3                1.00  0
# 11             30             6        1.0     3                0.90  1
#
# [271 rows x 10 columns]

# %%
scaled_exp_vars = scaler.transform(num_df_test)
num_df_test = pd.DataFrame(scaled_exp_vars,columns = num_df_test.columns)
num_df_test.head()
# Out:
#    price  review_scores_rating  number_of_reviews  security_deposit  \
# 0   69.0                  85.0              255.0             100.0
# 1  125.0                  99.0               21.0             200.0
# 2  165.0                  95.0                4.0             150.0
# 3  114.0                 100.0                4.0             500.0
# 4  275.0                  96.0               67.0             200.0
#
#    cleaning_fee  accommodates  bathrooms  beds  host_response_rate  \
# 0          72.0           3.0        1.0   1.0                 1.0
# 1          40.0           2.0        1.0   1.0                 1.0
# 2          65.0           3.0        1.0   2.0                 1.0
# 3          50.0           6.0        1.0   4.0                 1.0
# 4         145.0           8.0        2.5   3.0                 1.0
#
#               y
# 0  1.306145e-17
# 1  1.306145e-17
# 2  1.306145e-17
# 3  1.306145e-17
# 4  1.000000e+00

# %% [markdown]
# ## 2. Full Model Classification
#
# ### 2.1. Full Logistic Regression Model
#
# First, let's fit the "full" model logistic regression model with our training dataset. In the interest of time, we'll call our "full" model the one that predicts the `probability that a host is a superhost` given the four explanatory variables below:
# * `review_scores_rating`
# * `number_of_reviews`
# * `neighborhood`
# * `room_type`
#
#
# Show the summary output table for this logistic regression model.

# %%
full_model = smf.logit(formula='y~review_scores_rating+number_of_reviews+neighborhood+room_type',data=df_train).fit()
full_model.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.431900
#          Iterations: 35
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   68
# Model:                          Logit   Df Residuals:                       59
# Method:                           MLE   Df Model:                            8
# Date:                Mon, 13 Nov 2023   Pseudo R-squ.:                  0.3348
# Time:                        02:01:33   Log-Likelihood:                -29.369
# converged:                      False   LL-Null:                       -44.149
# Covariance Type:            nonrobust   LLR p-value:                 0.0002528
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                     -32.2247     12.229     -2.635      0.008     -56.194      -8.256
# neighborhood[T.Broadway]       -1.3672      0.883     -1.548      0.122      -3.098       0.364
# neighborhood[T.Fremont]        -2.0616      1.384     -1.490      0.136      -4.774       0.651
# neighborhood[T.Minor]          -0.8299      1.211     -0.685      0.493      -3.204       1.544
# neighborhood[T.Wallingford]    -0.2392      0.940     -0.254      0.799      -2.081       1.603
# room_type[T.Private room]      -1.2184      1.050     -1.160      0.246      -3.277       0.840
# room_type[T.Shared room]      -28.6540   9.62e+05  -2.98e-05      1.000   -1.89e+06    1.88e+06
# review_scores_rating            0.3312      0.124      2.678      0.007       0.089       0.574
# number_of_reviews               0.0248      0.011      2.303      0.021       0.004       0.046
# ===============================================================================================
# """

# %% [markdown]
# ### 2.2. Test Dataset ROC Curve
#
# Now, create an ROC curve for this logistic regression model and the **test dataset**. Also calculate the AUC of this ROC curve.

# %%
df_test['predictive_prob'] = full_model.predict(df_test)
df_test[['predictive_prob','y']].head()
# Out:
#      predictive_prob  y
# 231         0.705910  0
# 259         0.428772  0
# 165         0.339497  0
# 89          0.540004  0
# 295         0.302630  1

# %%
fprs,tprs,thresholds = roc_curve(y_true = df_test['y'],y_score=df_test['predictive_prob'])

# %%
pd.DataFrame({'fpr':fprs,'tpr':tprs})
# Out:
#           fpr       tpr
# 0    0.000000  0.000000
# 1    0.005155  0.000000
# 2    0.005155  0.012987
# 3    0.015464  0.012987
# 4    0.015464  0.051948
# ..        ...       ...
# 113  0.886598  1.000000
# 114  0.896907  1.000000
# 115  0.907216  1.000000
# 116  0.927835  1.000000
# 117  1.000000  1.000000
#
# [118 rows x 2 columns]

# %%
auc = roc_auc_score(y_true=df_test['y'],y_score=df_test['predictive_prob'])
auc
# Out:
# 0.7470210202168965

# %%
def plot_roc(fpr,tpr,auc,lw=2):
    plt.plot(fpr,tpr,color='darkorange',lw=lw,label='ROC curve (area = '+str(round(auc,3))+')')
    plt.plot([0,1],[0,1],color='navy',lw=lw,linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Pos
               itive Rate')
    plt.title('ROC Curve')
    plt.legend(loc="lower right")
    plt.show()

# %%
plot_roc(fprs,tprs,auc)

# %% [markdown]
# ### 2.3. Interpreting the Test ROC and AUC
#
# 1. Suppose we were to use the full logistic regression model to classify the observations in the test dataset. Does there exist a predictive probability threshold that we could use that would create a classification of the test dataset with close to perfect FPR and TPR? Explain.
# 2. Evaluate how well the full logistic regression model would do in general when it comes to classifying the test dataset.

# %% [markdown]
# 1. The true positive rate (TPR) and false positive rate (FPR) are both usually at a tradeoff meaning that when TPR is higher FPR is lower and the other way around. We would want a model that has an fpr that is 0 or close to 0 and a tpr that is 1 or close to 1. As can be seen from the graph the ROC curve curves in a way that makes it impossible to find a threshold in which we have a fpr that is close to 0 and tpr that is close to 1.
#
# 2. The full logistic regression model would do  well in classifying the test dataset as can be seen by the moderately high AUC value of 0.747.

# %% [markdown]
# ### 2.4. Evaluating the Full Logistic Regression Model with Respect to the Primary Research Goal
#
# Based on our analysis above, how well might the full logistic regression model do when it comes to classifying *new Airbnb hosts* as either a super host or not a superhost? Explain.

# %% [markdown]
# The full logistic regression model would do well in classifying new Airbnb hosts as either a super host or non superhost. We can tell because of the high AUC value of 0.747 which is close to 1. This means that it is able to distinguish between Superhosts and non-Superhosts better than random chance.

# %% [markdown]
# ## 3. Backwards Elimination
#
# Now let's suppose we would like to try to find the logistic regression model that will yield the **highest test dataset AUC**. Use a backwards elimination algorithm to search for the logistic regression model that will yield the **highest test dataset AUC**.

# %%
full_model = smf.logit(formula='y~review_scores_rating+number_of_reviews+neighborhood+room_type',data=df_train).fit()
full_model.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.431900
#          Iterations: 35
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   68
# Model:                          Logit   Df Residuals:                       59
# Method:                           MLE   Df Model:                            8
# Date:                Tue, 14 Nov 2023   Pseudo R-squ.:                  0.3348
# Time:                        11:29:03   Log-Likelihood:                -29.369
# converged:                      False   LL-Null:                       -44.149
# Covariance Type:            nonrobust   LLR p-value:                 0.0002528
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                     -32.2247     12.229     -2.635      0.008     -56.194      -8.256
# neighborhood[T.Broadway]       -1.3672      0.883     -1.548      0.122      -3.098       0.364
# neighborhood[T.Fremont]        -2.0616      1.384     -1.490      0.136      -4.774       0.651
# neighborhood[T.Minor]          -0.8299      1.211     -0.685      0.493      -3.204       1.544
# neighborhood[T.Wallingford]    -0.2392      0.940     -0.254      0.799      -2.081       1.603
# room_type[T.Private room]      -1.2184      1.050     -1.160      0.246      -3.277       0.840
# room_type[T.Shared room]      -28.6540   9.62e+05  -2.98e-05      1.000   -1.89e+06    1.88e+06
# review_scores_rating            0.3312      0.124      2.678      0.007       0.089       0.574
# number_of_reviews               0.0248      0.011      2.303      0.021       0.004       0.046
# ===============================================================================================
# """

# %%
#Full model TEST DATA predictive probabilities
df_test['predictive prob'] = full_model.predict(df_test)

#Full model TEST DATA AUC
auc = roc_auc_score(y_true=df_test['y'],y_score=df_test['predictive_prob'])
auc
# Out:
# 0.7549538090775203

# %%
#REDUCED MODEL 1 no rating
red1_mod = smf.logit(formula='y~number_of_reviews+neighborhood+room_type',data=df_train).fit()

#REDUCED MODEL 1 test data predictive probabilities
df_test['predictive_prob'] = red1_mod.predict(df_test)

#REDUCED MODEL 1 test data AUC
auc = roc_auc_score(y_true=df_test['y'],y_score=df_test['predictive_prob'])
auc
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.537405
#          Iterations: 35
# 0.641350917124113

# %%
#REDUCED MODEL 2 no number reviews
red2_mod = smf.logit(formula='y~review_scores_rating+neighborhood+room_type',data=df_train).fit()

#REDUCED MODEL 2 test data predictive probabilities
df_test['predictive_prob'] = red2_mod.predict(df_test)

#REDUCED MODEL 2 test data AUC
auc = roc_auc_score(y_true=df_test['y'],y_score=df_test['predictive_prob'])
auc
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.478700
#          Iterations: 35
# 0.687039764359352

# %%
#REDUCED MODEL 3 no neighborhood
red3_mod = smf.logit(formula='y~review_scores_rating+number_of_reviews+room_type',data=df_train).fit()

#REDUCED MODEL 3 test data predictive probabilities
df_test['predictive_prob'] = red3_mod.predict(df_test)

#REDUCED MODEL 3 test data AUC
auc = roc_auc_score(y_true=df_test['y'],y_score=df_test['predictive_prob'])
auc
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.465140
#          Iterations: 35
# 0.7501338867318249

# %%
#REDUCED MODEL 4 no room type
red4_mod = smf.logit(formula='y~review_scores_rating+number_of_reviews+neighborhood',data=df_train).fit()

#REDUCED MODEL 4 test data predictive probabilities
df_test['predictive_prob'] = red4_mod.predict(df_test)

#REDUCED MODEL 4 test data AUC
auc = roc_auc_score(y_true=df_test['y'],y_score=df_test['predictive_prob'])
auc
# Out:
# Optimization terminated successfully.
#          Current function value: 0.465225
#          Iterations 8
# 0.7549538090775203

# %%
#FULL MODEL 2 no room type
full2_mod = smf.logit(formula='y~review_scores_rating+number_of_reviews+neighborhood',data=df_train).fit()

#FULL MODEL 2 test data predictive probabilities
df_test['predictive_prob'] = full2_mod.predict(df_test)

#FULL MODEL 2 test data AUC
auc = roc_auc_score(y_true=df_test['y'],y_score=df_test['predictive_prob'])
auc
# Out:
# Optimization terminated successfully.
#          Current function value: 0.465225
#          Iterations 8
# 0.7549538090775203

# %%
#2 - REDUCED MODEL 1 no rating
red1_mod = smf.logit(formula='y~+number_of_reviews+neighborhood',data=df_train).fit()

#2 - REDUCED MODEL 1 test data predictive probabilities
df_test['predictive_prob'] = red1_mod.predict(df_test)

#2 - REDUCED MODEL 1 test data AUC
auc = roc_auc_score(y_true=df_test['y'],y_score=df_test['predictive_prob'])
auc
# Out:
# Optimization terminated successfully.
#          Current function value: 0.566607
#          Iterations 6
# 0.6322466193600216

# %%
#2 - REDUCED MODEL 2 no reviews
red2_mod = smf.logit(formula='y~review_scores_rating+neighborhood',data=df_train).fit()

#2 - REDUCED MODEL 2 test data predictive probabilities
df_test['predictive_prob'] = red2_mod.predict(df_test)

#2 - REDUCED MODEL 2 test data AUC
auc = roc_auc_score(y_true=df_test['y'],y_score=df_test['predictive_prob'])
auc
# Out:
# Optimization terminated successfully.
#          Current function value: 0.513611
#          Iterations 8
# 0.6893158388003748

# %%
#2 - REDUCED MODEL 3 no neighborhood
red3_mod = smf.logit(formula='y~review_scores_rating+number_of_reviews',data=df_train).fit()

#2 - REDUCED MODEL 3 test data predictive probabilities
df_test['predictive_prob'] = red3_mod.predict(df_test)

#2 - REDUCED MODEL 3 test data AUC
auc = roc_auc_score(y_true=df_test['y'],y_score=df_test['predictive_prob'])
auc
# Out:
# Optimization terminated successfully.
#          Current function value: 0.508411
#          Iterations 8
# 0.7590373543981791

# %%
#FULL MODEL 3 no neighborhood
red3_mod = smf.logit(formula='y~review_scores_rating+number_of_reviews',data=df_train).fit()

#FULL MODEL 3 test data predictive probabilities
df_test['predictive_prob'] = red3_mod.predict(df_test)

#FULL MODEL 3 test data AUC
auc = roc_auc_score(y_true=df_test['y'],y_score=df_test['predictive_prob'])
auc
# Out:
# Optimization terminated successfully.
#          Current function value: 0.508411
#          Iterations 8
# 0.7590373543981791

# %%
#3 - REDUCED MODEL 1 no rating
red3_mod = smf.logit(formula='y~number_of_reviews',data=df_train).fit()

#3 - REDUCED MODEL 1 test data predictive probabilities
df_test['predictive_prob'] = red3_mod.predict(df_test)

#3 - REDUCED MODEL 1 test data AUC
auc = roc_auc_score(y_true=df_test['y'],y_score=df_test['predictive_prob'])
auc
# Out:
# Optimization terminated successfully.
#          Current function value: 0.629816
#          Iterations 5
# 0.6697014325880306

# %%
#3 - REDUCED MODEL 2 no reviews
red3_mod = smf.logit(formula='y~review_scores_rating',data=df_train).fit()

#3 - REDUCED MODEL 2 test data predictive probabilities
df_test['predictive_prob'] = red3_mod.predict(df_test)

#3 - REDUCED MODEL 2 test data AUC
auc = roc_auc_score(y_true=df_test['y'],y_score=df_test['predictive_prob'])
auc
# Out:
# Optimization terminated successfully.
#          Current function value: 0.558426
#          Iterations 8
# 0.7135828089436336

# %%
#FINAL MODEL
final_mod = smf.logit(formula='y~review_scores_rating+number_of_reviews',data=df_train).fit()

#FINAL MODEL test data predictive probabilities
df_test['predictive_prob'] = final_mod.predict(df_test)

#FINAL MODEL test data AUC
auc = roc_auc_score(y_true=df_test['y'],y_score=df_test['predictive_prob'])
auc
# Out:
# Optimization terminated successfully.
#          Current function value: 0.508411
#          Iterations 8
# 0.7590373543981791

# %% [markdown]
# ## 4. Selecting the Best Final Model Classification
#
# Now, we would like to use our final logistic regression model that we selected in #3 to create a classification that best meets our research goals.
#
# ### 4.1. Test ROC and AUC
#
# Plot the ROC curve for this final logistic regression model and the test dataset.

# %%
fprs,tprs,thresholds = roc_curve(y_true = df_test['y'],y_score=df_test['predictive_prob'])
auc = roc_auc_score(y_true=df_test['y'],y_score=df_test['predictive_prob'])
plot_roc(fprs,tprs,auc)

# %% [markdown]
# ### 4.2. Specific Classifier Use Case
#
# Suppose that you work as a data scientist at Airbnb and you would like to design a new automated algorithm which predicts whether or not an Airbnb listing host is deserving of an Superhost status (based on the observations in this dataset). To keep existing superhosts happy, you would **ideally like for as many of the people in this dataset who are already superhosts to be awarded (ie. predicted) to be a superhost**. On the other hand, suppose that your boss has decided that **at most 25% of nonsuperhosts should be expected to be misclassified as a superhost in new datasets.**
#
# Practically speaking you'd be classifying hosts as superhosts vs. nonsuperhosts for *new datasets*.
#
# 1. If we were to use the final logistic regression from #3, what predictive probability threshold should we use to create a classification that best meets these specific research goals and specifications?
# 2. What false positive rate and true positive rate would the test dataset classification have if we were to use this predictive probability threshold?

# %%
def fpr_tpr_thresh(y,pred_prob,thresh):
    yhat = 1*(pred_prob >= thresh)
    tn, fp, fn, tp = confusion_matrix(y_true=y, y_pred=yhat).ravel()
    tpr = tp / (fn + tp)
    fpr = fp / (fp + tn)
    tnr = tn / (tn + fp)
    fnr = fn / (fn + tp)
    return pd.DataFrame({'threshold':[thresh],'fpr':[fpr],'tpr':[tpr], 'tnr':[tnr], 'fnr':[fnr]})

# %%
fpr_tpr_thresh(df_test['y'],df_test['predictive_prob'],0.25)
# Out:
#    threshold       fpr       tpr       tnr       fnr
# 0       0.25  0.505155  0.883117  0.494845  0.116883

# %%
for thresh in np.arange(0,1.01,.01):
    print(fpr_tpr_thresh(df_test['y'],df_test['predictive_prob'],thresh))
# Out:
#    threshold  fpr  tpr  tnr  fnr
# 0        0.0  1.0  1.0  0.0  0.0
#    threshold       fpr       tpr       tnr       fnr
# 0       0.01  0.902062  0.987013  0.097938  0.012987
#    threshold       fpr       tpr       tnr       fnr
# 0       0.02  0.886598  0.987013  0.113402  0.012987
#    threshold       fpr       tpr       tnr       fnr
# 0       0.03  0.876289  0.987013  0.123711  0.012987
#    threshold       fpr       tpr       tnr       fnr
# 0       0.04  0.814433  0.987013  0.185567  0.012987
#    threshold       fpr       tpr       tnr       fnr
# 0       0.05  0.804124  0.987013  0.195876  0.012987
#    threshold       fpr       tpr       tnr       fnr
# 0       0.06  0.773196  0.987013  0.226804  0.012987
#    threshold       fpr       tpr       tnr       fnr
# 0       0.07  0.757732  0.987013  0.242268  0.012987
#    threshold       fpr       tpr       tnr       fnr
# 0       0.08  0.752577  0.974026  0.247423  0.025974
#    threshold       fpr       tpr       tnr       fnr
# 0       0.09  0.737113  0.974026  0.262887  0.025974
#    threshold       fpr       tpr       tnr       fnr
# 0        0.1  0.716495  0.961039  0.283505  0.038961
#    threshold      fpr       tpr      tnr       fnr
# 0       0.11  0.71134  0.961039  0.28866  0.038961
#    threshold       fpr       tpr       tnr       fnr
# 0       0.12  0.701031  0.961039  0.298969  0.038961
#    threshold       fpr       tpr       tnr       fnr
# 0       0.13  0.680412  0.961039  0.319588  0.038961
#    threshold       fpr       tpr       tnr       fnr
# 0       0.14  0.659794  0.961039  0.340206  0.038961
#    threshold       fpr       tpr       tnr       fnr
# 0       0.15  0.659794  0.961039  0.340206  0.038961
#    threshold       fpr       tpr       tnr       fnr
# 0       0.16  0.618557  0.961039  0.381443  0.038961
#    threshold       fpr       tpr       tnr       fnr
# 0       0.17  0.592784  0.961039  0.407216  0.038961
#    threshold       fpr       tpr       tnr       fnr
# 0       0.18  0.587629  0.961039  0.412371  0.038961
#    threshold       fpr       tpr       tnr       fnr
# 0       0.19  0.572165  0.922078  0.427835  0.077922
#    threshold      fpr       tpr      tnr       fnr
# 0        0.2  0.56701  0.922078  0.43299  0.077922
#    threshold       fpr       tpr       tnr       fnr
# 0       0.21  0.561856  0.922078  0.438144  0.077922
#    threshold       fpr       tpr       tnr       fnr
# 0       0.22  0.541237  0.909091  0.458763  0.090909
#    threshold       fpr       tpr       tnr       fnr
# 0       0.23  0.530928  0.909091  0.469072  0.090909
#    threshold       fpr       tpr       tnr       fnr
# 0       0.24  0.510309  0.883117  0.489691  0.116883
#    threshold       fpr       tpr       tnr       fnr
# 0       0.25  0.505155  0.883117  0.494845  0.116883
#    threshold       fpr      tpr       tnr      fnr
# 0       0.26  0.489691  0.87013  0.510309  0.12987
#    threshold       fpr       tpr       tnr       fnr
# 0       0.27  0.479381  0.857143  0.520619  0.142857
#    threshold       fpr       tpr       tnr       fnr
# 0       0.28  0.453608  0.857143  0.546392  0.142857
#    threshold       fpr       tpr       tnr       fnr
# 0       0.29  0.438144  0.857143  0.561856  0.142857
#    threshold       fpr       tpr       tnr       fnr
# 0        0.3  0.427835  0.805195  0.572165  0.194805
#    threshold      fpr       tpr      tnr       fnr
# 0       0.31  0.42268  0.792208  0.57732  0.207792
#    threshold       fpr       tpr       tnr       fnr
# 0       0.32  0.417526  0.766234  0.582474  0.233766
#    threshold       fpr       tpr       tnr       fnr
# 0       0.33  0.402062  0.766234  0.597938  0.233766
#    threshold       fpr       tpr       tnr       fnr
# 0       0.34  0.391753  0.753247  0.608247  0.246753
#    threshold       fpr      tpr       tnr      fnr
# 0       0.35  0.381443  0.74026  0.618557  0.25974
#    threshold       fpr      tpr       tnr      fnr
# 0       0.36  0.360825  0.74026  0.639175  0.25974
#    threshold      fpr       tpr      tnr       fnr
# 0       0.37  0.35567  0.701299  0.64433  0.298701
#    threshold       fpr       tpr       tnr       fnr
# 0       0.38  0.345361  0.688312  0.654639  0.311688
#    threshold       fpr       tpr       tnr       fnr
# 0       0.39  0.335052  0.649351  0.664948  0.350649
#    threshold       fpr       tpr       tnr       fnr
# 0        0.4  0.324742  0.649351  0.675258  0.350649
#    threshold       fpr       tpr       tnr       fnr
# 0       0.41  0.319588  0.649351  0.680412  0.350649
#    threshold       fpr       tpr       tnr       fnr
# 0       0.42  0.319588  0.636364  0.680412  0.363636
#    threshold       fpr      tpr       tnr      fnr
# 0       0.43  0.319588  0.61039  0.680412  0.38961
#    threshold       fpr      tpr       tnr      fnr
# 0       0.44  0.319588  0.61039  0.680412  0.38961
#    threshold       fpr      tpr       tnr      fnr
# 0       0.45  0.304124  0.61039  0.695876  0.38961
#    threshold       fpr      tpr       tnr      fnr
# 0       0.46  0.304124  0.61039  0.695876  0.38961
#    threshold       fpr       tpr       tnr       fnr
# 0       0.47  0.304124  0.597403  0.695876  0.402597
#    threshold       fpr       tpr       tnr       fnr
# 0       0.48  0.293814  0.584416  0.706186  0.415584
#    threshold       fpr       tpr       tnr       fnr
# 0       0.49  0.242268  0.532468  0.757732  0.467532
#    threshold       fpr       tpr       tnr       fnr
# 0        0.5  0.164948  0.493506  0.835052  0.506494
#    threshold       fpr       tpr       tnr       fnr
# 0       0.51  0.128866  0.428571  0.871134  0.571429
#    threshold       fpr       tpr       tnr       fnr
# 0       0.52  0.097938  0.402597  0.902062  0.597403
#    threshold       fpr       tpr       tnr       fnr
# 0       0.53  0.082474  0.363636  0.917526  0.636364
#    threshold       fpr       tpr       tnr       fnr
# 0       0.54  0.072165  0.337662  0.927835  0.662338
#    threshold      fpr       tpr      tnr       fnr
# 0       0.55  0.06701  0.311688  0.93299  0.688312
#    threshold      fpr       tpr      tnr       fnr
# 0       0.56  0.06701  0.285714  0.93299  0.714286
#    threshold       fpr       tpr       tnr       fnr
# 0       0.57  0.061856  0.246753  0.938144  0.753247
#    threshold       fpr       tpr       tnr       fnr
# 0       0.58  0.061856  0.233766  0.938144  0.766234
#    threshold       fpr       tpr       tnr       fnr
# 0       0.59  0.041237  0.233766  0.958763  0.766234
#    threshold       fpr       tpr       tnr       fnr
# 0        0.6  0.041237  0.233766  0.958763  0.766234
#    threshold       fpr       tpr       tnr       fnr
# 0       0.61  0.030928  0.220779  0.969072  0.779221
#    threshold       fpr       tpr       tnr       fnr
# 0       0.62  0.025773  0.207792  0.974227  0.792208
#    threshold       fpr       tpr       tnr       fnr
# 0       0.63  0.025773  0.194805  0.974227  0.805195
#    threshold       fpr       tpr       tnr       fnr
# 0       0.64  0.025773  0.168831  0.974227  0.831169
#    threshold       fpr       tpr       tnr       fnr
# 0       0.65  0.025773  0.168831  0.974227  0.831169
#    threshold       fpr       tpr       tnr       fnr
# 0       0.66  0.025773  0.155844  0.974227  0.844156
#    threshold       fpr       tpr       tnr       fnr
# 0       0.67  0.025773  0.155844  0.974227  0.844156
#    threshold       fpr       tpr       tnr       fnr
# 0       0.68  0.025773  0.142857  0.974227  0.857143
#    threshold       fpr       tpr       tnr       fnr
# 0       0.69  0.020619  0.142857  0.979381  0.857143
#    threshold       fpr       tpr       tnr       fnr
# 0        0.7  0.015464  0.142857  0.984536  0.857143
#    threshold       fpr       tpr       tnr       fnr
# 0       0.71  0.015464  0.142857  0.984536  0.857143
#    threshold       fpr       tpr       tnr       fnr
# 0       0.72  0.010309  0.142857  0.989691  0.857143
#    threshold       fpr      tpr       tnr      fnr
# 0       0.73  0.010309  0.12987  0.989691  0.87013
#    threshold       fpr       tpr       tnr       fnr
# 0       0.74  0.010309  0.116883  0.989691  0.883117
#    threshold       fpr       tpr       tnr       fnr
# 0       0.75  0.010309  0.103896  0.989691  0.896104
#    threshold       fpr       tpr       tnr       fnr
# 0       0.76  0.010309  0.090909  0.989691  0.909091
#    threshold       fpr       tpr       tnr       fnr
# 0       0.77  0.010309  0.090909  0.989691  0.909091
#    threshold       fpr       tpr       tnr       fnr
# 0       0.78  0.010309  0.090909  0.989691  0.909091
#    threshold       fpr       tpr       tnr       fnr
# 0       0.79  0.010309  0.090909  0.989691  0.909091
#    threshold       fpr       tpr       tnr       fnr
# 0        0.8  0.010309  0.077922  0.989691  0.922078
#    threshold       fpr       tpr       tnr       fnr
# 0       0.81  0.010309  0.064935  0.989691  0.935065
#    threshold       fpr       tpr       tnr       fnr
# 0       0.82  0.005155  0.051948  0.994845  0.948052
#    threshold       fpr       tpr       tnr       fnr
# 0       0.83  0.005155  0.038961  0.994845  0.961039
#    threshold       fpr       tpr       tnr       fnr
# 0       0.84  0.005155  0.038961  0.994845  0.961039
#    threshold       fpr       tpr       tnr       fnr
# 0       0.85  0.005155  0.025974  0.994845  0.974026
#    threshold       fpr       tpr       tnr       fnr
# 0       0.86  0.005155  0.012987  0.994845  0.987013
#    threshold       fpr       tpr       tnr       fnr
# 0       0.87  0.005155  0.012987  0.994845  0.987013
#    threshold       fpr       tpr       tnr       fnr
# 0       0.88  0.005155  0.012987  0.994845  0.987013
#    threshold       fpr  tpr       tnr  fnr
# 0       0.89  0.005155  0.0  0.994845  1.0
#    threshold       fpr  tpr       tnr  fnr
# 0        0.9  0.005155  0.0  0.994845  1.0
#    threshold       fpr  tpr       tnr  fnr
# 0       0.91  0.005155  0.0  0.994845  1.0
#    threshold       fpr  tpr       tnr  fnr
# 0       0.92  0.005155  0.0  0.994845  1.0
#    threshold       fpr  tpr       tnr  fnr
# 0       0.93  0.005155  0.0  0.994845  1.0
#    threshold  fpr  tpr  tnr  fnr
# 0       0.94  0.0  0.0  1.0  1.0
#    threshold  fpr  tpr  tnr  fnr
# 0       0.95  0.0  0.0  1.0  1.0
#    threshold  fpr  tpr  tnr  fnr
# 0       0.96  0.0  0.0  1.0  1.0
#    threshold  fpr  tpr  tnr  fnr
# 0       0.97  0.0  0.0  1.0  1.0
#    threshold  fpr  tpr  tnr  fnr
# 0       0.98  0.0  0.0  1.0  1.0
#    threshold  fpr  tpr  tnr  fnr
# 0       0.99  0.0  0.0  1.0  1.0
#    threshold  fpr  tpr  tnr  fnr
# 0        1.0  0.0  0.0  1.0  1.0

# %% [markdown]
#    threshold       fpr       tpr       tnr       fnr
# a.       0.07  0.757732  0.987013  0.242268  0.012987

# %% [markdown]
# ### 4.3. Specificity and Sensitivity
#
# What is the specificity and sensitivity of the test dataset classification that you selected in #4.2?

# %%
sensitivity = 0.987013 / (0.987013 + 0.012987)

sensitivity
# Out:
# 0.987013

# %%
specificity = 0.242268 / (0.242268 + 0.757732)

specificity
# Out:
# 0.242268

# %% [markdown]
# ## 5. Interpreting the Final Logistic Regression Model
#
# Finally, let's interpret the final logistic regression model selected in #3.
#
# ### 5.1. Logistic Regression Equation
#
# First, put this final model into a logistic regression equation. Your equation should have the predictive probability on the left hand side. Make sure to use appropriate notation discussed in class.

# %%
final_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   68
# Model:                          Logit   Df Residuals:                       65
# Method:                           MLE   Df Model:                            2
# Date:                Tue, 14 Nov 2023   Pseudo R-squ.:                  0.2169
# Time:                        18:59:27   Log-Likelihood:                -34.572
# converged:                       True   LL-Null:                       -44.149
# Covariance Type:            nonrobust   LLR p-value:                 6.931e-05
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept              -33.9406     11.219     -3.025      0.002     -55.930     -11.951
# review_scores_rating     0.3386      0.114      2.982      0.003       0.116       0.561
# number_of_reviews        0.0232      0.010      2.313      0.021       0.004       0.043
# ========================================================================================
# """

# %% [markdown]
# $\hat{p}=\frac{1}{1+e^{-(-33.9406+0.3386review_scores_rating + 0.02320.2724number_of_reviews)}}$

# %% [markdown]
# ### 5.2. Final Model Multicollinearity
#
# Does your final model have an issue with multicollinearity? Explain.

# %% [markdown]
# The cell doesn't have an issue with multicollinearity. As can be seen in the final model summary table, neither of the correlation coefficients for the variables are particularly strong. They are 0.3386 and 0.0232. That being said it can be seen that the final model wouldn't have an issue with multicollinearity.

# %% [markdown]
# ### 5.3. Predictive Power
#
# Finally, what two explanatory (or indicator) variables are suggested to bring the most predictive power to the final model? Do you have any concerns about making this interpretation?

# %% [markdown]
# The two indicator variables I believe bring the most predictive power to the final model are review_scores_rating and number_of_reviews. These are the strongest predictors as can be seen through the backwards elimination algorithm.

# %% [markdown]
# ### 5.4. Overfitting Variables
#
# Based on the results of our backwards elimination algorithm, do you have any reason to believe that any of the explanatory variables in the full model were overfitting the model? If so, which one(s)?

# %% [markdown]
# I think roomtype and neighborhood were the two explanatory variables that were overfitting the model.

# %% [markdown]
# # 🎉🎉🎉 Congratulations on finishing the final lab assignment! 🎉🎉🎉
